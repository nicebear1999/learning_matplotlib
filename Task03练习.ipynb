# %% [markdown]
# ### 1. 墨尔本1981年至1990年的每月温度情况

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
# Out:
#       Time  Temperature
# 0  1981-01    17.712903
# 1  1981-02    17.678571
# 2  1981-03    13.500000
# 3  1981-04    12.356667
# 4  1981-05     9.490323
# 5  1981-06     7.306667
# 6  1981-07     7.577419
# 7  1981-08     7.238710
# 8  1981-09    10.143333
# 9  1981-10    10.087097

# %%
ex1 = pd.read_csv('./data/layout_ex1.csv')
fig, axs=plt.subplots(2, 5, figsize=(15, 4), sharex=True, sharey=True)
fig.suptitle('墨尔本温度曲线', size=20)

for i in range(2):
    for j in range(5):
        y=ex1['Temperature'][(i*5+j)*12:(i*5+j+1)*12]
        axs[i][j].plot(range(1,13), y)
        axs[i][j].set_title('%d年'%(1981+i*5+j))
        plt.xticks(range(1,13))
        if j==0: axs[i][j].set_ylabel('气温')
fig.tight_layout()

# %% [markdown]
# ### 2. 画出数据的散点图和边际分布
#
# - 用 `np.random.randn(2, 150)` 生成一组二维数据，使用两种非均匀子图的分割方法，做出该数据对应的散点图和边际分布图

# %%
import numpy as np
datax=np.random.randn(2, 150)

# %%
fig = plt.figure(figsize=(10, 10))
spec = fig.add_gridspec(nrows=2, ncols=2, width_ratios=[5,1], height_ratios=[1,5])
ax = fig.add_subplot(spec[1, 0])
ax.scatter(datax[0],datax[1])
ax = fig.add_subplot(spec[0, 0])
plt.axis('off')
ax.hist(datax[0])
ax = fig.add_subplot(spec[1, 1])
ax.hist(datax[1],orientation='horizontal')
plt.axis('off')
fig.tight_layout()
